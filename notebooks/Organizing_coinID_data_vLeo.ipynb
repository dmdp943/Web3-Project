# %% [markdown]
# ## Organizing CoinID Data

# %%
import pandas as pd
import requests
import json
import ast
from datetime import datetime
import time
format_date = lambda x: datetime.fromtimestamp(int(x)/1000)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re
import requests
import xmltodict

# %%
df_coinID = pd.read_csv("..//raw_data//df_coinID_index_as_columns.csv")

# %%
df_coinID.set_index("Unnamed: 0", inplace = True)

# %%
df_coinID.rename_axis(None, axis = 0, inplace = True)

# %%
df_coinID
# Out:
#                                                                             01coin  \
# id                                                                          01coin
# symbol                                                                         zoc
# name                                                                        01coin
# asset_platform_id                                                              NaN
# platforms                                                                 {'': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                        NeoScrypt
# categories                                                         ['Masternodes']
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '01coin', 'de': '01coin', 'es': '01coin...
# description                      {'en': '', 'de': '', 'es': '', 'fr': '', 'it':...
# links                            {'homepage': ['https://01coin.io/', '', ''], '...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                                2463
# coingecko_score                                                             14.726
# developer_score                                                             44.667
# community_score                                                             15.272
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.00131885, 'ars': 0...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 11, 'stars': 15, 'subscribers': 7, '...
# public_interest_stats                {'alexa_rank': 4678489, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-14T20:55:04.466Z
# tickers                          [{'base': 'ZOC', 'target': 'BTC', 'market': {'...
# ico_data                                                                       NaN
#
#                                                           0-5x-long-algorand-token  \
# id                                                        0-5x-long-algorand-token
# symbol                                                                    algohalf
# name                                                      0.5X Long Algorand Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Algorand Token', 'de': '0.5X...
# description                      {'en': '0.5X Long Algorand Token (ALGOHALF) is...
# links                            {'homepage': ['https://ftx.com/tokens/ALGOHALF...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               12804
# coingecko_score                                                                0.2
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 54131, 'ars': 165019...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-07T23:29:37.597Z
# tickers                                                                         []
# ico_data                                                                       NaN
#
#                                                      0-5x-long-altcoin-index-token  \
# id                                                   0-5x-long-altcoin-index-token
# symbol                                                                     althalf
# name                                                 0.5X Long Altcoin Index Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Altcoin Index Token', 'de': ...
# description                      {'en': '0.5X Long Altcoin Index Token (ALTHALF...
# links                            {'homepage': ['https://ftx.com/tokens/ALTHALF'...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               13244
# coingecko_score                                                                0.0
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                0.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 73744, 'ars': 225230...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-09T23:07:43.082Z
# tickers                          [{'base': 'ALTHALF', 'target': 'USD', 'market'...
# ico_data                                                                       NaN
#
#                                                     0-5x-long-ascendex-token-token  \
# id                                                  0-5x-long-ascendex-token-token
# symbol                                                                     asdhalf
# name                                                0.5X Long AscendEx Token Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long AscendEx Token Token', 'de':...
# description                      {'en': '0.5X Long AscendEx Token (BTMX) Token ...
# links                            {'homepage': ['https://ftx.com/trade/ASDHALF/U...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               13159
# coingecko_score                                                                0.0
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                0.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 55865, 'ars': 168767...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-03-27T12:32:17.499Z
# tickers                                                                         []
# ico_data                                                                       NaN
#
#                                                       0-5x-long-bitcoin-cash-token  \
# id                                                    0-5x-long-bitcoin-cash-token
# symbol                                                                     bchhalf
# name                                                  0.5X Long Bitcoin Cash Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Bitcoin Cash Token', 'de': '...
# description                      {'en': '0.5X Long Bitcoin Cash Token (BCHHALF)...
# links                            {'homepage': ['https://ftx.com/tokens/BCHHALF'...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               12978
# coingecko_score                                                                0.2
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 31595, 'ars': 970972...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-14T21:32:03.369Z
# tickers                          [{'base': 'BCHHALF', 'target': 'USD', 'market'...
# ico_data                                                                       NaN
#
#                                                            0-5x-long-bitcoin-token  \
# id                                                         0-5x-long-bitcoin-token
# symbol                                                                        half
# name                                                       0.5X Long Bitcoin Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                     ['Leveraged Token']
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Bitcoin Token', 'de': '0.5X ...
# description                      {'en': '0.5X Long Bitcoin Token (HALF) is an E...
# links                            {'homepage': ['https://ftx.com/tokens/HALF', '...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               12868
# coingecko_score                                                                0.2
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 57666, 'ars': 176979...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-12T17:58:35.483Z
# tickers                          [{'base': 'HALF', 'target': 'USD', 'market': {...
# ico_data                                                                       NaN
#
#                                                            0-5x-long-cardano-token  \
# id                                                         0-5x-long-cardano-token
# symbol                                                                     adahalf
# name                                                       0.5X Long Cardano Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Cardano Token', 'de': '0.5X ...
# description                      {'en': '0.5X Long Cardano Token (ADAHALF) is a...
# links                            {'homepage': ['https://ftx.com/tokens/ADAHALF'...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               12648
# coingecko_score                                                                0.2
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 148144, 'ars': 45956...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T02:40:35.425Z
# tickers                          [{'base': 'ADAHALF', 'target': 'USD', 'market'...
# ico_data                                                                       NaN
#
#                                                          0-5x-long-chainlink-token  \
# id                                                       0-5x-long-chainlink-token
# symbol                                                                    linkhalf
# name                                                     0.5X Long Chainlink Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Chainlink Token', 'de': '0.5...
# description                      {'en': '0.5X Long Chainlink Token (LINKHALF) i...
# links                            {'homepage': ['https://ftx.com/tokens/LINKHALF...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               13230
# coingecko_score                                                                0.0
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                0.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 61241, 'ars': 183991...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-03-26T17:56:48.661Z
# tickers                                                                         []
# ico_data                                                                       NaN
#
#                                                             0-5x-long-cosmos-token  \
# id                                                          0-5x-long-cosmos-token
# symbol                                                                    atomhalf
# name                                                        0.5X Long Cosmos Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Cosmos Token', 'de': '0.5X L...
# description                      {'en': '0.5X Long Cosmos Token (ATOMHALF) is a...
# links                            {'homepage': ['https://ftx.com/tokens/ATOMHALF...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               13140
# coingecko_score                                                                0.0
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                0.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 90445, 'ars': 277097...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-11T21:54:34.739Z
# tickers                          [{'base': 'ATOMHALF', 'target': 'USD', 'market...
# ico_data                                                                       NaN
#
#                                                           0-5x-long-dogecoin-token  \
# id                                                        0-5x-long-dogecoin-token
# symbol                                                                    dogehalf
# name                                                      0.5X Long Dogecoin Token
# asset_platform_id                                                         ethereum
# platforms                                                         {'ethereum': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': '0.5X Long Dogecoin Token', 'de': '0.5X...
# description                      {'en': '0.5X Long Dogecoin Token (DOGEHALF) is...
# links                            {'homepage': ['https://ftx.com/tokens/dogehalf...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               12458
# coingecko_score                                                                0.2
# developer_score                                                                0.0
# community_score                                                                0.0
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 396583, 'ars': 12170...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': 5253, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-13T05:49:49.392Z
# tickers                          [{'base': 'DOGEHALF', 'target': 'USD', 'market...
# ico_data                                                                       NaN
#
#                                  ...  \
# id                               ...
# symbol                           ...
# name                             ...
# asset_platform_id                ...
# platforms                        ...
# block_time_in_minutes            ...
# hashing_algorithm                ...
# categories                       ...
# public_notice                    ...
# additional_notices               ...
# localization                     ...
# description                      ...
# links                            ...
# image                            ...
# country_origin                   ...
# genesis_date                     ...
# sentiment_votes_up_percentage    ...
# sentiment_votes_down_percentage  ...
# market_cap_rank                  ...
# coingecko_rank                   ...
# coingecko_score                  ...
# developer_score                  ...
# community_score                  ...
# liquidity_score                  ...
# public_interest_score            ...
# market_data                      ...
# community_data                   ...
# developer_data                   ...
# public_interest_stats            ...
# status_updates                   ...
# last_updated                     ...
# tickers                          ...
# ico_data                         ...
#
#                                                                           polylion  \
# id                                                                        polylion
# symbol                                                                        lion
# name                                                                      PolyLion
# asset_platform_id                                                      polygon-pos
# platforms                        {'polygon-pos': '0x1da554d34027ca8de74c5b1cd2f...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': 'PolyLion', 'de': 'PolyLion', 'es': 'Po...
# description                      {'en': "PolyLion is a 1st Next Generation Auto...
# links                            {'homepage': ['https://polylion.exchange/', ''...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                  US
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               10764
# coingecko_score                                                              1.684
# developer_score                                                                0.0
# community_score                                                              6.745
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.00031425, 'ars': 0...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T14:33:44.453Z
# tickers                          [{'base': '0X0D500B1D8E8EF31E21C99D1DB9A6444D3...
# ico_data                                                                       NaN
#
#                                                                            zatcoin  \
# id                                                                         zatcoin
# symbol                                                                     zatcoin
# name                                                                       ZatCoin
# asset_platform_id                                              binance-smart-chain
# platforms                        {'binance-smart-chain': '0x958e030e5937414b8b5...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                       ['Binance Smart Chain Ecosystem']
# public_notice                                                                  NaN
# additional_notices               ["Kindly be aware of <a href='https://www.coin...
# localization                     {'en': 'ZatCoin', 'de': 'ZatCoin', 'es': 'ZatC...
# description                      {'en': '"Zatcoin tools brings safety, security...
# links                            {'homepage': ['https://zatcoin.io', '', ''], '...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                100.0
# sentiment_votes_down_percentage                                                0.0
# market_cap_rank                                                                NaN
# coingecko_rank                                                                6790
# coingecko_score                                                              3.839
# developer_score                                                                0.0
# community_score                                                             16.542
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 2.939e-05, 'ars': 0....
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:26:44.766Z
# tickers                          [{'base': '0X958E030E5937414B8B54E4647FB513E34...
# ico_data                                                                       NaN
#
#                                                                          solo-coin  \
# id                                                                       solo-coin
# symbol                                                                        solo
# name                                                                     Sologenic
# asset_platform_id                                                              xrp
# platforms                                                              {'xrp': ''}
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                   ['Finance / Banking']
# public_notice                         Sologenic is previously named as "SOLO Coin"
# additional_notices                                                              []
# localization                     {'en': 'Sologenic', 'de': 'Sologenic', 'es': '...
# description                      {'en': 'Sologenic is introducing a sophisticat...
# links                            {'homepage': ['https://www.sologenic.com/', ''...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                  EE
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                92.68
# sentiment_votes_down_percentage                                               7.32
# market_cap_rank                                                                NaN
# coingecko_rank                                                                2611
# coingecko_score                                                             14.138
# developer_score                                                                0.0
# community_score                                                              37.96
# liquidity_score                                                             28.936
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 2.11, 'ars': 65.57, ...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                {'alexa_rank': 1252833, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:28:19.274Z
# tickers                          [{'base': 'SOLO', 'target': 'USDT', 'market': ...
# ico_data                                                                       NaN
#
#                                                                         olympus-v1  \
# id                                                                      olympus-v1
# symbol                                                                         ohm
# name                                                                    Olympus v1
# asset_platform_id                                                         ethereum
# platforms                        {'ethereum': '0x383518188c0c6d7730d91b2c03a03c...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                       ['Rebase Tokens', 'Decentralized Finance (DeFi...
# public_notice                    Olympus has migrated to v2: https://www.coinge...
# additional_notices                                                              []
# localization                     {'en': 'Olympus v1', 'de': 'Olympus v1', 'es':...
# description                      {'en': '', 'de': '', 'es': '', 'fr': '', 'it':...
# links                            {'homepage': ['https://olympusdao.finance/', '...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  0.0
# sentiment_votes_down_percentage                                              100.0
# market_cap_rank                                                                NaN
# coingecko_rank                                                                6492
# coingecko_score                                                              4.346
# developer_score                                                                0.0
# community_score                                                             11.119
# liquidity_score                                                              9.496
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 260.83, 'ars': 8094....
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:28:56.163Z
# tickers                          [{'base': '0X383518188C0C6D7730D91B2C03A03C837...
# ico_data                                                                       NaN
#
#                                                                         safeinsure  \
# id                                                                      safeinsure
# symbol                                                                        sins
# name                                                                    SafeInsure
# asset_platform_id                                                              NaN
# platforms                                                                 {'': ''}
# block_time_in_minutes                                                            1
# hashing_algorithm                                                            Quark
# categories                                                      ['Cryptocurrency']
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': 'SafeInsure', 'de': 'SafeInsure', 'es':...
# description                      {'en': 'Safeinsure is a decentralized insuranc...
# links                            {'homepage': ['https://www.safeinsure.io/', ''...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                               3486
# coingecko_rank                                                                2156
# coingecko_score                                                             16.037
# developer_score                                                             25.809
# community_score                                                              6.572
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.00742773, 'ars': 0...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                {'alexa_rank': 3963373, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:25:18.897Z
# tickers                          [{'base': 'SINS', 'target': 'BTC', 'market': {...
# ico_data                                                                       NaN
#
#                                                                             thekey  \
# id                                                                          thekey
# symbol                                                                         tky
# name                                                                        THEKEY
# asset_platform_id                                                              neo
# platforms                        {'neo': '132947096727c84c7f9e076c90f08fec3bc17...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                            ['Big Data']
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': 'THEKEY', 'de': 'THEKEY', 'es': 'THEKEY...
# description                      {'en': 'THEKEY Project is developing a second-...
# links                            {'homepage': ['http://www.thekey.vip/', '', ''...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                  CN
# genesis_date                                                            2018-01-28
# sentiment_votes_up_percentage                                                  0.0
# sentiment_votes_down_percentage                                              100.0
# market_cap_rank                                                               2444
# coingecko_rank                                                                1142
# coingecko_score                                                             21.584
# developer_score                                                             14.018
# community_score                                                             35.592
# liquidity_score                                                              1.214
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.0005835, 'ars': 0....
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 1, 'stars': 14, 'subscribers': 3, 't...
# public_interest_stats                {'alexa_rank': 3643426, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:26:34.883Z
# tickers                          [{'base': 'TKY', 'target': 'ETH', 'market': {'...
# ico_data                         {'ico_start_date': '2018-02-01T00:00:00.000Z',...
#
#                                                                           mooncake  \
# id                                                                        mooncake
# symbol                                                                        moon
# name                                                                      MoonCake
# asset_platform_id                                              binance-smart-chain
# platforms                        {'binance-smart-chain': '0x2e8c05582176fa93b45...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': 'MoonCake', 'de': 'MoonCake', 'es': 'Mo...
# description                      {'en': 'Mooncake is the first frictionless yie...
# links                            {'homepage': ['https://mooncake.io/', 'https:/...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                  ID
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                                6373
# coingecko_score                                                              4.503
# developer_score                                                                0.0
# community_score                                                              19.56
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.0155287, 'ars': 0....
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-14T17:15:15.184Z
# tickers                          [{'base': '0X0E09FABB73BD3ADE0A17ECC321FD13A19...
# ico_data                                                                       NaN
#
#                                                                     wolf-game-wool  \
# id                                                                  wolf-game-wool
# symbol                                                                        wool
# name                                                                Wolf Game Wool
# asset_platform_id                                                         ethereum
# platforms                        {'ethereum': '0x8355dbe8b0e275abad27eb843f3eaf...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': 'Wolf Game Wool', 'de': 'Wolf Game Wool...
# description                      {'en': 'The utility and governance token of Wo...
# links                            {'homepage': ['https://wolf.game/', '', ''], '...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                 75.0
# sentiment_votes_down_percentage                                               25.0
# market_cap_rank                                                                NaN
# coingecko_rank                                                                5429
# coingecko_score                                                              5.889
# developer_score                                                                0.0
# community_score                                                              10.14
# liquidity_score                                                             18.291
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.306721, 'ars': 9.5...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:28:59.734Z
# tickers                          [{'base': '0X8355DBE8B0E275ABAD27EB843F3EAF3FC...
# ico_data                                                                       NaN
#
#                                                                          misty-inu  \
# id                                                                       misty-inu
# symbol                                                                       misty
# name                                                                     Misty Inu
# asset_platform_id                                                         ethereum
# platforms                        {'ethereum': '0x814e8f8e35ac8bab913326364ca47b...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                                                                  NaN
# additional_notices                                                              []
# localization                     {'en': 'Misty Inu', 'de': 'Misty Inu', 'es': '...
# description                      {'en': 'Our purpose is to unite small cap toke...
# links                            {'homepage': ['https://www.mistyinuwaifu.com/'...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                  NaN
# sentiment_votes_down_percentage                                                NaN
# market_cap_rank                                                                NaN
# coingecko_rank                                                               11834
# coingecko_score                                                              1.164
# developer_score                                                                0.0
# community_score                                                              5.289
# liquidity_score                                                                0.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.00027307, 'ars': 0...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-01-22T02:57:33.418Z
# tickers                                                                         []
# ico_data                                                                       NaN
#
#                                                                        mintstarter
# id                                                                     mintstarter
# symbol                                                                        mint
# name                                                                   MintStarter
# asset_platform_id                                                         ethereum
# platforms                        {'ethereum': '0x583673b49ee3ae9e59c0b2fa662115...
# block_time_in_minutes                                                            0
# hashing_algorithm                                                              NaN
# categories                                                                      []
# public_notice                    The following token has a variable tax functio...
# additional_notices               ["Kindly be aware of <a href='https://www.coin...
# localization                     {'en': 'MintStarter', 'de': 'MintStarter', 'es...
# description                      {'en': 'MintStarter takes the development hass...
# links                            {'homepage': ['https://mintstarter.app ', '', ...
# image                            {'thumb': 'https://assets.coingecko.com/coins/...
# country_origin                                                                 NaN
# genesis_date                                                                   NaN
# sentiment_votes_up_percentage                                                100.0
# sentiment_votes_down_percentage                                                0.0
# market_cap_rank                                                                NaN
# coingecko_rank                                                                9511
# coingecko_score                                                              1.994
# developer_score                                                                0.0
# community_score                                                              8.155
# liquidity_score                                                                1.0
# public_interest_score                                                          0.0
# market_data                      {'current_price': {'aed': 0.01292058, 'ars': 0...
# community_data                   {'facebook_likes': None, 'twitter_followers': ...
# developer_data                   {'forks': 0, 'stars': 0, 'subscribers': 0, 'to...
# public_interest_stats                   {'alexa_rank': None, 'bing_matches': None}
# status_updates                                                                  []
# last_updated                                              2022-04-15T22:29:35.783Z
# tickers                          [{'base': '0X583673B49EE3AE9E59C0B2FA662115952...
# ico_data                                                                       NaN
#
# [33 rows x 13675 columns]

# %%
def function_check_null(coin_market_data,coin_community_data):
    try:
        coin_market_data['total_value_locked']
    except KeyError:
        coin_market_data['total_value_locked']=np.nan

    try:
        coin_market_data['mcap_to_tvl_ratio']
    except KeyError:
        coin_market_data['mcap_to_tvl_ratio']=np.nan

    try:
        coin_market_data['fdv_to_tvl_ratio']
    except KeyError:
        coin_market_data['fdv_to_tvl_ratio']=np.nan

    try:
        coin_market_data['roi']
    except KeyError:
        coin_market_data['roi']=np.nan

    try:
        coin_market_data['ath']['usd']
    except KeyError:
        coin_market_data['ath']['usd']=np.nan

    try:
        coin_market_data['ath']['btc']
    except KeyError:
        coin_market_data['ath']['btc']=np.nan

    try:
        coin_market_data['ath']['eth']
    except KeyError:
        coin_market_data['ath']['eth']=np.nan

    try:
        coin_market_data['ath_change_percentage']['usd']
    except KeyError:
        coin_market_data['ath_change_percentage']['usd']=np.nan

    try:
        coin_market_data['ath_change_percentage']['btc']
    except KeyError:
        coin_market_data['ath_change_percentage']['btc']=np.nan

    try:
        coin_market_data['ath_change_percentage']['eth']
    except KeyError:
        coin_market_data['ath_change_percentage']['eth']=np.nan

    try:
        coin_market_data['ath_date']['usd']
    except KeyError:
        coin_market_data['ath_date']['usd']=np.nan

    try:
        coin_market_data['ath_date']['btc']
    except KeyError:
        coin_market_data['ath_date']['btc']=np.nan

    try:
        coin_market_data['ath_date']['eth']
    except KeyError:
        coin_market_data['ath_date']['eth']=np.nan

    try:
        coin_market_data['atl']['usd']
    except KeyError:
        coin_market_data['atl']['usd']=np.nan

    try:
        coin_market_data['atl']['btc']
    except KeyError:
        coin_market_data['atl']['btc']=np.nan

    try:
        coin_market_data['atl']['eth']
    except KeyError:
        coin_market_data['atl']['eth']=np.nan

    try:
        coin_market_data['atl_change_percentage']['usd']
    except KeyError:
        coin_market_data['atl_change_percentage']['usd']=np.nan

    try:
        coin_market_data['atl_change_percentage']['btc']
    except KeyError:
        coin_market_data['atl_change_percentage']['btc']=np.nan

    try:
        coin_market_data['atl_change_percentage']['eth']
    except KeyError:
        coin_market_data['atl_change_percentage']['eth']=np.nan

    try:
        coin_market_data['atl_date']['usd']
    except KeyError:
        coin_market_data['atl_date']['usd']=np.nan

    try:
        coin_market_data['atl_date']['btc']
    except KeyError:
        coin_market_data['atl_date']['btc']=np.nan

    try:
        coin_market_data['atl_date']['eth']
    except KeyError:
        coin_market_data['atl_date']['eth']=np.nan

    try:
        coin_market_data['market_cap']['usd']
    except KeyError:
        coin_market_data['market_cap']['usd']=np.nan

    try:
        coin_market_data['market_cap']['btc']
    except KeyError:
        coin_market_data['market_cap']['btc']=np.nan

    try:
        coin_market_data['market_cap']['eth']
    except KeyError:
        coin_market_data['market_cap']['eth']=np.nan

    try:
        coin_market_data['market_cap_rank']
    except KeyError:
        coin_market_data['market_cap_rank']=np.nan

    try:
        coin_community_data['facebook_likes']
    except KeyError:
        coin_community_data['facebook_likes']=np.nan

    try:
        coin_community_data['twitter_followers']
    except KeyError:
        coin_community_data['twitter_followers']=np.nan

    try:
        coin_community_data['reddit_average_posts_48h']
    except KeyError:
        coin_community_data['reddit_average_posts_48h']=np.nan

    try:
        coin_community_data['reddit_average_comments_48h']
    except KeyError:
        coin_community_data['reddit_average_comments_48h']=np.nan

    try:
        coin_community_data['reddit_subscribers']
    except KeyError:
        coin_community_data['reddit_subscribers']=np.nan

    try:
        coin_community_data['reddit_accounts_active_48h']
    except KeyError:
        coin_community_data['reddit_accounts_active_48h']=np.nan

    try:
        coin_community_data['telegram_channel_user_count']
    except KeyError:
        coin_community_data['telegram_channel_user_count']=np.nan
    
    return coin_market_data, coin_community_data

# %%
coin_data = {}
coin_list = []

for coin in df_coinID:
    #converting necessary strings to dict
    coin_market_data = ast.literal_eval(df_coinID[coin]['market_data'])
    coin_community_data = ast.literal_eval(df_coinID[coin]['community_data'])
    coin_description = ast.literal_eval(df_coinID[coin]['description'])
    coin_categories = ast.literal_eval(df_coinID[coin]['categories'])
    
    coin_market_data, coin_community_data = function_check_null(coin_market_data,coin_community_data)

    coin_data = {\
                 # symbols, names and static data
                 'id' : df_coinID[coin]['id'], 
                 'symbol' : df_coinID[coin]['symbol'],
                 'name' : df_coinID[coin]['symbol'],
                 'asset_platform_id' : df_coinID[coin]['asset_platform_id'],
                 'block_time_in_minutes' : df_coinID[coin]['block_time_in_minutes'],
                 'hashing_algorithm' : df_coinID[coin]['hashing_algorithm'],
                 'categories' : coin_categories,
                 'description' : coin_description['en'],
                 'country_origin' : df_coinID[coin]['country_origin'],
                 'genesis_date' : df_coinID[coin]['genesis_date'],
                 'sentiment_votes_up_percentage' : df_coinID[coin]['sentiment_votes_up_percentage'],
                 'sentiment_votes_down_percentage' : df_coinID[coin]['sentiment_votes_down_percentage'],
                 'market_cap_rank' : df_coinID[coin]['market_cap_rank'],
                 'coingecko_rank' : df_coinID[coin]['coingecko_rank'],
                 'coingecko_score' : df_coinID[coin]['coingecko_score'],
                 'developer_score' : df_coinID[coin]['developer_score'],
                 'community_score' : df_coinID[coin]['community_score'],
                 'liquidity_score' : df_coinID[coin]['liquidity_score'],
                 'public_interest_score' : df_coinID[coin]['public_interest_score'],
                 
                 
                 # market data
                 'total_value_locked' : coin_market_data['total_value_locked'],
                 'mcap_to_tvl_ratio' : coin_market_data['mcap_to_tvl_ratio'],
                 'fdv_to_tvl_ratio' : coin_market_data['fdv_to_tvl_ratio'],
                 'roi' : coin_market_data['roi'],
                 
                 
                 #market data - ath data
                 'ath_usd' : coin_market_data['ath']['usd'],
                 'ath_btc' : coin_market_data['ath']['btc'],
                 'ath_eth' : coin_market_data['ath']['eth'],
                 'ath_change_percentage_usd' : coin_market_data['ath_change_percentage']['usd'],
                 'ath_change_percentage_btc' : coin_market_data['ath_change_percentage']['btc'],
                 'ath_change_percentage_eth' : coin_market_data['ath_change_percentage']['eth'],
                 'ath_date_usd' : coin_market_data['ath_date']['usd'],
                 'ath_date_btc' : coin_market_data['ath_date']['btc'],
                 'ath_date_eth' : coin_market_data['ath_date']['eth'],
                 
                 
                 #market data - atl data
                 'atl_usd' : coin_market_data['atl']['usd'],
                 'atl_btc' : coin_market_data['atl']['btc'],
                 'atl_eth' : coin_market_data['atl']['eth'],
                 'atl_change_percentage_usd' : coin_market_data['atl_change_percentage']['usd'],
                 'atl_change_percentage_btc' : coin_market_data['atl_change_percentage']['btc'],
                 'atl_change_percentage_eth' : coin_market_data['atl_change_percentage']['eth'],
                 'atl_date_usd' : coin_market_data['atl_date']['usd'],
                 'atl_date_btc' : coin_market_data['atl_date']['btc'],
                 'atl_date_eth' : coin_market_data['atl_date']['eth'],
                 
                 
                 #market data - market cap data
                 'market_cap_usd' : coin_market_data['market_cap']['usd'],
                 'market_cap_btc' : coin_market_data['market_cap']['btc'],
                 'market_cap_eth' : coin_market_data['market_cap']['eth'],
                 'market_cap_rank' : coin_market_data['market_cap_rank'],
                 
                 
                 #community data
                 'facebook_likes' : coin_community_data['facebook_likes'],
                 'twitter_followers' : coin_community_data['twitter_followers'],
                 'reddit_average_posts_48h' : coin_community_data['reddit_average_posts_48h'],
                 'reddit_average_comments_48h' : coin_community_data['reddit_average_comments_48h'],
                 'reddit_subscribers' : coin_community_data['reddit_subscribers'],
                 'reddit_accounts_active_48h' : coin_community_data['reddit_accounts_active_48h'],
                 'telegram_channel_user_count' : coin_community_data['telegram_channel_user_count'],
                 
                 
                 #developers data
                 'developer_data' : df_coinID[coin]['developer_data'],
                 'public_interest_stats' : df_coinID[coin]['public_interest_stats']
                }
    
    #adding coin data to the main list
    coin_list.append(coin_data)

# %% [markdown]
# **Para solucionar**:
# - Categories ta como STR, mas preciso converter em list para pegar as categorias mesmo, tem projetos com mais de uma categoria, pensando em pegar a primeiro.
# - Transformar STR em dictionary ou json para extrair informacao de market_data.

# %% [markdown]
# **Excluidos**:
# - public_notice - string de avisos desnecessarios
# - additional_notice - string de avisos desnecessarios
# - localization - so tem o nome dependendo da localizacao
# - description em idiomas que nao sao ingles - nao vai ser util
# - link - nao vai ser util
# - image - nao vai ser util
# ----
# droppar pos criacao de dataset
# - facebook_likes - nao tem nada
# - block_time_in_minutes - nao vai ser util
# - country_origin - pq tem 10600 nulls, demais para ser util
# - genesis_date - tem muitos vazios tambem.
# - total_value_locked - por ter muitos nulls
# - mcap_to_tvl_ratio - infelizmente, pois tem nulls demais tb
# - fdv_to_tvl_ratio - muitos nulls
# - roi - nulls demais
# - informacoes do reddit - tem mais de 10K com ZERO no geral.
# ----
# anotacoes
# - hashing_algorithm - super interessante, mas temos poucos, a maioria seria NaN - entender melhor se vale deixar considerando os NaN
# - developer_data - no momento, nao sei como usar

# %%
coin_df = pd.DataFrame(coin_list)

# %% [markdown]
# ### Using information of coins in the coinranking ICO list only

# %%
# some urls of coinrank
url_coins = 'https://cryptorank.io/sitemap-coins.xml'

response = requests.get(url_coins)
urlcoins_data = xmltodict.parse(response.content)

url_list = []
for url in urlcoins_data['urlset']['url']:
    url_list.append(url['loc'])
    
coin_names = []
for row in url_list:
    if row.rsplit('/')[3] == 'ico':
        coin_names.append(row.rsplit('/')[4])

# %%
#match list of everything that is in coingecko and cryptorank
match_list_cg_cr = list(set(coin_df['id']) & set(coin_names))

# %%
coin_df['in_cryptorank'] = 0

for coin in match_list_cg_cr:
    if coin in list(coin_df['id']):
        row_index = coin_df.index[coin_df['id'] == coin].tolist()[0]
        coin_df['in_cryptorank'].iloc[row_index] = 1
        #coin_df_test['in_cryptorank'].iloc[coin_df_test['id'].
# Out:
# /tmp/ipykernel_7623/3426141193.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coin_df['in_cryptorank'].iloc[row_index] = 1

# %%
coin_df[coin_df['in_cryptorank'] == 1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1209 entries, 20 to 13670
# Data columns (total 54 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               1209 non-null   object
#  1   symbol                           1209 non-null   object
#  2   name                             1209 non-null   object
#  3   asset_platform_id                1111 non-null   object
#  4   block_time_in_minutes            1209 non-null   object
#  5   hashing_algorithm                53 non-null     object
#  6   categories                       1209 non-null   object
#  7   description                      1209 non-null   object
#  8   country_origin                   390 non-null    object
#  9   genesis_date                     178 non-null    object
#  10  sentiment_votes_up_percentage    789 non-null    object
#  11  sentiment_votes_down_percentage  789 non-null    object
#  12  market_cap_rank                  766 non-null    float64
#  13  coingecko_rank                   1208 non-null   object
#  14  coingecko_score                  1209 non-null   object
#  15  developer_score                  1209 non-null   object
#  16  community_score                  1209 non-null   object
#  17  liquidity_score                  1209 non-null   object
#  18  public_interest_score            1209 non-null   object
#  19  total_value_locked               142 non-null    object
#  20  mcap_to_tvl_ratio                121 non-null    object
#  21  fdv_to_tvl_ratio                 128 non-null    object
#  22  roi                              262 non-null    object
#  23  ath_usd                          1187 non-null   float64
#  24  ath_btc                          1187 non-null   float64
#  25  ath_eth                          1187 non-null   float64
#  26  ath_change_percentage_usd        1209 non-null   float64
#  27  ath_change_percentage_btc        1209 non-null   float64
#  28  ath_change_percentage_eth        1209 non-null   float64
#  29  ath_date_usd                     1187 non-null   object
#  30  ath_date_btc                     1187 non-null   object
#  31  ath_date_eth                     1187 non-null   object
#  32  atl_usd                          1187 non-null   float64
#  33  atl_btc                          1187 non-null   float64
#  34  atl_eth                          1187 non-null   float64
#  35  atl_change_percentage_usd        1209 non-null   float64
#  36  atl_change_percentage_btc        1209 non-null   float64
#  37  atl_change_percentage_eth        1209 non-null   float64
#  38  atl_date_usd                     1187 non-null   object
#  39  atl_date_btc                     1187 non-null   object
#  40  atl_date_eth                     1187 non-null   object
#  41  market_cap_usd                   1187 non-null   float64
#  42  market_cap_btc                   1187 non-null   float64
#  43  market_cap_eth                   1187 non-null   float64
#  44  facebook_likes                   0 non-null      object
#  45  twitter_followers                1209 non-null   float64
#  46  reddit_average_posts_48h         1209 non-null   float64
#  47  reddit_average_comments_48h      1209 non-null   float64
#  48  reddit_subscribers               1209 non-null   int64
#  49  reddit_accounts_active_48h       1209 non-null   int64
#  50  telegram_channel_user_count      1128 non-null   float64
#  51  developer_data                   1209 non-null   object
#  52  public_interest_stats            1209 non-null   object
#  53  in_cryptorank                    1209 non-null   int64
# dtypes: float64(20), int64(3), object(31)
# memory usage: 519.5+ KB

# %% [markdown]
# ### Transforming Types

# %%
coin_df.drop(columns = ['block_time_in_minutes', 'genesis_date', 'total_value_locked', 'mcap_to_tvl_ratio', 'fdv_to_tvl_ratio', \
                        'roi', 'ath_usd', 'ath_btc', 'ath_eth', 'ath_change_percentage_usd', 'ath_change_percentage_btc',
                       'ath_change_percentage_eth', 'ath_date_usd', 'ath_date_btc', 'ath_date_eth', 'atl_usd', 'atl_btc', 
                       'atl_eth', 'atl_change_percentage_usd', 'atl_change_percentage_btc', 'atl_change_percentage_eth', 
                        'atl_date_usd', 'atl_date_btc', 'atl_date_eth', 'market_cap_usd', 'market_cap_btc', 'market_cap_eth',
                       'facebook_likes', 'reddit_average_posts_48h', 'reddit_average_comments_48h', 'reddit_subscribers', 
                       'reddit_accounts_active_48h', 'developer_data', 'public_interest_stats', 'in_cryptorank', 'developer_score','public_interest_score'], inplace = True)

# %%
coin_df.dtypes
# Out:
# id                                  object
# symbol                              object
# name                                object
# asset_platform_id                   object
# hashing_algorithm                   object
# categories                          object
# description                         object
# country_origin                      object
# sentiment_votes_up_percentage       object
# sentiment_votes_down_percentage     object
# market_cap_rank                    float64
# coingecko_rank                      object
# coingecko_score                     object
# community_score                     object
# liquidity_score                     object
# twitter_followers                  float64
# telegram_channel_user_count        float64
# dtype: object

# %%
str_cols = ['id', 'symbol', 'name', 'asset_platform_id', 'hashing_algorithm','description','country_origin']
coin_df[str_cols] = coin_df[str_cols].astype(str)
float_cols = ['sentiment_votes_up_percentage', 'sentiment_votes_down_percentage','market_cap_rank', ]
coin_df[float_cols] = coin_df[float_cols].astype(float)
int_cols = ['coingecko_rank', 'coingecko_score','community_score', 'liquidity_score', 'twitter_followers',
       'telegram_channel_user_count']

# %%
coin_df.to_parquet("..//raw_data//coin_id_formated.parquet")
