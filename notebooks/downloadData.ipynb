# %%
import pandas as pd
import requests
from datetime import datetime
format_date = lambda x: datetime.fromtimestamp(int(x)/1000)

# %%
req = requests.get("https://api.coingecko.com/api/v3/coins/list")
df = pd.DataFrame(req.json())
df
# Out:
#                                    id    symbol  \
# 0                              01coin       zoc
# 1            0-5x-long-algorand-token  algohalf
# 2       0-5x-long-altcoin-index-token   althalf
# 3      0-5x-long-ascendex-token-token   asdhalf
# 4        0-5x-long-bitcoin-cash-token   bchhalf
# ...                               ...       ...
# 13666                            zyro      zyro
# 13667                           zyrri       zyr
# 13668                   zytara-dollar      zusd
# 13669                             zyx       zyx
# 13670                  zzz-finance-v2     zzzv2
#
#                                  name
# 0                              01coin
# 1            0.5X Long Algorand Token
# 2       0.5X Long Altcoin Index Token
# 3      0.5X Long AscendEx Token Token
# 4        0.5X Long Bitcoin Cash Token
# ...                               ...
# 13666                            Zyro
# 13667                           Zyrri
# 13668                   Zytara Dollar
# 13669                             ZYX
# 13670                  zzz.finance v2
#
# [13671 rows x 3 columns]

# %%
res = {}

for coin in df['id']:
    try:
        req = requests.get(f"https://api.coingecko.com/api/v3/coins/{coin}/ohlc?vs_currency=usd&days=max")
        resp = req.json()
        dados = pd.DataFrame(resp)
        dados.columns = ['Date','Open', 'High', 'Low', 'Close']
        dados['Date'] = dados['Date'].apply(format_date)
        dados.set_index('Date', inplace=True)

        dados.columns = pd.MultiIndex.from_product([[coin], dados.columns])
        res[coin] = dados
    except Exception as e:
        print(coin)
# Out:
# 01coin
# 0-5x-long-algorand-token
# 0-5x-long-altcoin-index-token
# 0-5x-long-ascendex-token-token
# 0-5x-long-bitcoin-cash-token
# 0-5x-long-bitcoin-token
# 0-5x-long-cardano-token
# 0-5x-long-chainlink-token
# 0-5x-long-cosmos-token
# 0-5x-long-dogecoin-token
# 0-5x-long-eos-token
# 0-5x-long-ethereum-classic-token
# 0-5x-long-ethereum-token
# 0-5x-long-kyber-network-token
# 0-5x-long-matic-token
# 0-5x-long-privacy-index-token
# 0-5x-long-swipe-token
# 0-5x-long-theta-network-token
# 0-5x-long-xrp-token
# 0cash
# 0chain
# 0x
# 0xcert
# 0xdao
# 0xdao-v2
# 0xmonero
# 0xpad
# 0x-wormhole
# 10024-10028-appoline
# 10084-grayton
# 100x-coin
# 10604-somerset
# 10612-somerset
# 10616-mckinney
# 10617-hathaway
# 10629-mckinney
# 10639-stratman
# 10700-whittier
# 11078-longview
# 11078-wayburn
# 11201-college
# 11300-roxbury
# 11653-nottingham
# 11957-olga
# 11-minutes
# 12334-lansdowne
# 12405-santa-rosa
# 12409-whitehill
# 1244-s-avers
# 12866-lauder
# 12ships
# 13045-wade
# 13114-glenfield
# 13116-kilbourne
# 1337
# 13606-winthrop
# 13991-warwick
# 14066-santa-rosa
# 14078-carlisle
# 14229-wilshire
# 14231-strathmoor
# 14319-rosemary
# 14494-chelsea
# 14825-wilfred
# 14882-troester
# 14918-joy
# 15039-ward
# 15048-freeland
# 15095-hartwell
# 15350-greydale
# 15373-parkside
# 1542-s-ridgeway
# 15634-liberal
# 15753-hartwell
# 15770-prest
# 15777-ardmore
# 15778-manor
# 15784-monte-vista
# 15796-hartwell
# 15860-hartwell
# 1617-s-avers
# 16200-fullerton
# 17500-evergreen
# 17809-charest
# 17813-bradford
# 1815-s-avers
# 18273-monte-vista
# 18276-appoline
# 18433-faust
# 18466-fielding
# 18481-westphalia
# 18776-sunderland
# 18900-mansfield
# 18983-alcoy
# 19020-rosemont
# 19136-tracey
# 19163-mitchell
# 19200-strasburg
# 19201-westphalia
# 19218-houghton
# 19311-keystone
# 19317-gable
# 19333-moenart
# 19596-goulburn
# 1beam
# 1x-short-okb-token
# 1x-short-privacy-index-token
# 1x-short-shitcoin-index-token
# 1x-short-swipe-token
# 1x-short-tezos-token
# 1x-short-theta-network-token
# 1x-short-tomochain-token
# 1x-short-trx-token
# 1x-short-vechain-token
# 1x-short-xrp-token
# 20200-lesure
# 2022moon
# 2030-floki
# 25097-andover
# 272-n-e-42nd-court
# 28vck
# 2acoin
# 2crazynft
# 2gather
# 2gether-2
# 2goshi
# 2key
# 2local-2
# 2omb-finance
# 2share
# 2x2
# 300fit
# 30mb-token
# 3432-harding
# 3shares
# 3x-long-algorand-token
# 3x-long-altcoin-index-token
# 3x-long-balancer-token
# 3x-long-bilira-token
# 3x-long-bitcoin-cash-token
# 3x-long-bitcoin-sv-token
# 3x-long-bitcoin-token
# 3x-long-bnb-token
# 3x-long-cardano-token
# 3x-long-chainlink-token
# 3x-long-compound-token-token
# 3x-long-compound-usdt-token
# 3x-long-cosmos-token
# 3x-long-defi-index-token
# 3x-long-dogecoin-token
# 3x-long-dragon-index-token
# 3x-long-eos-token
# 3x-long-ethereum-classic-token
# 3x-long-ethereum-token
# 3x-long-exchange-token-index-token
# 3x-long-huobi-token-token
# 3x-long-kyber-network-token
# 3x-long-leo-token
# 3x-long-litecoin-token
# 3x-long-maker-token
# 3x-long-matic-token
# 3x-long-midcap-index-token
# 3x-long-okb-token
# 3x-long-pax-gold-token
# 3x-long-privacy-index-token
# 3x-long-shitcoin-index-token
# 3x-long-stellar-token
# 3x-long-sushi-token
# 3x-long-swipe-token
# 3x-long-tether-gold-token
# 3x-long-tether-token
# 3x-long-tezos-token
# 3x-long-theta-network-token
# 3x-long-tomochain-token
# 3x-long-trx-token
# 3x-long-vechain-token
# 3x-long-xrp-token
# 3x-long-zcash-token
# 3x-short-altcoin-index-token
# 3x-short-balancer-token
# 3x-short-bilira-token
# 3x-short-bitcoin-cash-token
# 3x-short-bitcoin-sv-token
# 3x-short-bitcoin-token
# 3x-short-bnb-token
# 3x-short-cardano-token
# 3x-short-chainlink-token
# 3x-short-compound-token-token
# 3x-short-compound-usdt-token
# 3x-short-defi-index-token
# 3x-short-dragon-index-token
# 3x-short-eos-token
# 3x-short-ethereum-classic-token
# 3x-short-ethereum-token
# 3x-short-exchange-token-index-token
# 3x-short-huobi-token-token
# 3x-short-kyber-network-token
# 3x-short-leo-token
# 3x-short-litecoin-token
# 3x-short-maker-token
# 3x-short-midcap-index-token
# 3x-short-okb-token
# 3x-short-pax-gold-token
# 3x-short-privacy-index-token
# 3x-short-shitcoin-index-token
# 3x-short-stellar-token
# 3x-short-sushi-token
# 3x-short-swipe-token
# 3x-short-tether-gold-token
# 3x-short-tether-token
# 3x-short-tezos-token
# 3x-short-trx-token
# 3x-short-vechain-token
# 3x-short-xrp-token
# 402-s-kostner
# 404
# 4061-grand
# 42-coin
# 4340-east-71
# 4380-beaconsfield
# 4680-buckingham
# 4852-4854-w-cortez
# 4artechnologies
# 4bulls
# 4int
# 4jnet
# 4mw
# 4new
# 4play
# 4-stock
# 50cent
# 50k
# 520
# 5601-s-wood
# 581-587-jefferson
# 5942-audubon
# 5g-cash
# 5table-finance
# 6923-greenview
# 7eleven
# 7plus-coin
# 7share
# 7up
# 808ta-token
# 8181-bliss
# 8342-schaefer
# 867
# 888tron
# 88mph
# 8bit-doge
# 8ight-finance
# 8pay
# 8x8-protocol
# 9133-devonshire
# 9165-kensington
# 9166-devonshire
# 9169-boleyn
# 9309-courville
# 9336-patton
# 9465-beaconsfield
# 9481-wayburn
# 9717-everts
# 9920-bishop
# 99starz
# a4-finance
# aag-ventures
# aananaapegarden
# aang-inu
# aaptitude
# aave
# aave-aave
# aave-amm-bptbalweth
# aave-amm-bptwbtcweth
# aave-amm-dai
# aave-amm-uniaaveweth
# aave-amm-unibatweth
# aave-amm-unicrvweth
# aave-amm-unidaiusdc
# aave-amm-unidaiweth
# aave-amm-unilinkweth
# aave-amm-unimkrweth
# aave-amm-unirenweth
# aave-amm-unisnxweth
# aave-amm-uniuniweth
# aave-amm-uniusdcweth
# aave-amm-uniwbtcusdc
# aave-amm-uniwbtcweth
# aave-amm-uniyfiweth
# aave-amm-usdc
# aave-amm-usdt
# aave-amm-wbtc
# aave-amm-weth
# aave-bal
# aave-balancer-pool-token
# aave-bat
# aave-bat-v1
# aave-busd
# aave-busd-v1
# aave-crv
# aave-dai
# aave-dai-v1
# aave-enj
# aave-enj-v1
# aave-eth-v1
# aavegotchi
# aavegotchi-alpha
# aavegotchi-fomo
# aavegotchi-fud
# aavegotchi-kek
# aave-gusd
# aave-interest-bearing-ampl
# aave-interest-bearing-steth
# aave-knc
# aave-knc-v1
# aave-link
# aave-link-v1
# aave-mana
# aave-mana-v1
# aave-mkr
# aave-mkr-v1
# aave-polygon-aave
# aave-polygon-dai
# aave-polygon-usdc
# aave-polygon-usdt
# aave-polygon-wbtc
# aave-polygon-weth
# aave-polygon-wmatic
# aave-rai
# aave-ren
# aave-ren-v1
# aave-snx
# aave-snx-v1
# aave-susd
# aave-susd-v1
# aave-tusd
# aave-tusd-v1
# aave-uni
# aave-usdc
# aave-usdc-v1
# aave-usdt
# aave-usdt-v1
# aave-wbtc
# aave-wbtc-v1
# aave-weth
# aave-wormhole
# aave-xsushi
# aave-yfi
# aave-zrx
# aave-zrx-v1
# aax-token
# abachi
# abacus
# abby-inu
# abc-chain
# abcc-token
# abell-coin
# abey
# abitshadow-token
# able-finance
# absolute
# absolute-sync-token
# absorber
# abulaba
# abura-farm
# acala
# acash-coin
# aca-token
# accel-defi
# accesslauncher
# ace-casino
# aced
# aced-2
# acent
# acestarter
# acetoken
# acet-token
# ac-exchange-token
# achain
# acknoledger
# ac-milan-fan-token
# acoconut
# acoin
# acreage-coin
# acryptos
# acryptosi
# acta-finance
# actinium
# action-coin
# activada
# active-world-rewards-token
# acuity-token
# acumen
# acu-platform
# acute-angle-cloud
# acy-finance
# adaboy
# adacash
# adadao
# adadex-tools
# adaflect
# adakong
# adalend
# adamant
# adamant-coin
# adamant-messenger
# adam-oracle
# adana-demirspor
# adapad
# adappter-token
# adaswap
# adax
# adbank
# addax
# addict-finance
# add-xyz-new
# adelphoi
# adena-finance
# adene
# adex
# ad-flex-token
# aditus

# %%
historical_price = pd.concat([res[i] for i in res], axis=1)
historical_price
# Out:
#                        01coin                                \
#                          Open      High       Low     Close
# Date
# 2017-06-14 21:00:00       NaN       NaN       NaN       NaN
# 2017-06-18 21:00:00       NaN       NaN       NaN       NaN
# 2017-06-22 21:00:00       NaN       NaN       NaN       NaN
# 2017-06-26 21:00:00       NaN       NaN       NaN       NaN
# 2017-06-29 21:00:00       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...
# 2022-03-30 21:00:00  0.000468  0.000817  0.000468  0.000817
# 2022-04-02 21:00:00  0.000706  0.000706  0.000463  0.000466
# 2022-04-06 21:00:00  0.000467  0.000467  0.000436  0.000436
# 2022-04-10 21:00:00  0.000611  0.000611  0.000424  0.000424
# 2022-04-14 21:00:00  0.000420  0.000435  0.000371  0.000371
#
#                     0-5x-long-algorand-token                                \
#                                         Open      High       Low     Close
# Date
# 2017-06-14 21:00:00                      NaN       NaN       NaN       NaN
# 2017-06-18 21:00:00                      NaN       NaN       NaN       NaN
# 2017-06-22 21:00:00                      NaN       NaN       NaN       NaN
# 2017-06-26 21:00:00                      NaN       NaN       NaN       NaN
# 2017-06-29 21:00:00                      NaN       NaN       NaN       NaN
# ...                                      ...       ...       ...       ...
# 2022-03-30 21:00:00                 15935.14  16211.44  15935.14  16211.44
# 2022-04-02 21:00:00                      NaN       NaN       NaN       NaN
# 2022-04-06 21:00:00                 14667.03  14667.03  14667.03  14667.03
# 2022-04-10 21:00:00                 14737.16  14737.16  14737.16  14737.16
# 2022-04-14 21:00:00                      NaN       NaN       NaN       NaN
#
#                     0-5x-long-altcoin-index-token            ...  \
#                                              Open      High  ...
# Date                                                         ...
# 2017-06-14 21:00:00                           NaN       NaN  ...
# 2017-06-18 21:00:00                           NaN       NaN  ...
# 2017-06-22 21:00:00                           NaN       NaN  ...
# 2017-06-26 21:00:00                           NaN       NaN  ...
# 2017-06-29 21:00:00                           NaN       NaN  ...
# ...                                           ...       ...  ...
# 2022-03-30 21:00:00                      20398.08  20740.75  ...
# 2022-04-02 21:00:00                           NaN       NaN  ...
# 2022-04-06 21:00:00                           NaN       NaN  ...
# 2022-04-10 21:00:00                      20077.42  20077.42  ...
# 2022-04-14 21:00:00                           NaN       NaN  ...
#
#                     15048-freeland        15095-hartwell                       \
#                                Low  Close           Open   High    Low  Close
# Date
# 2017-06-14 21:00:00            NaN    NaN            NaN    NaN    NaN    NaN
# 2017-06-18 21:00:00            NaN    NaN            NaN    NaN    NaN    NaN
# 2017-06-22 21:00:00            NaN    NaN            NaN    NaN    NaN    NaN
# 2017-06-26 21:00:00            NaN    NaN            NaN    NaN    NaN    NaN
# 2017-06-29 21:00:00            NaN    NaN            NaN    NaN    NaN    NaN
# ...                            ...    ...            ...    ...    ...    ...
# 2022-03-30 21:00:00          56.74  57.15          57.13  58.01  57.13  57.55
# 2022-04-02 21:00:00          55.20  55.68          55.58  56.56  55.58  56.07
# 2022-04-06 21:00:00          52.47  52.47          56.75  56.98  52.84  52.84
# 2022-04-10 21:00:00          51.32  51.93          53.19  53.19  51.68  52.01
# 2022-04-14 21:00:00          47.99  50.07          48.30  50.55  48.30  50.55
#
#                     15350-greydale
#                               Open   High    Low  Close
# Date
# 2017-06-14 21:00:00            NaN    NaN    NaN    NaN
# 2017-06-18 21:00:00            NaN    NaN    NaN    NaN
# 2017-06-22 21:00:00            NaN    NaN    NaN    NaN
# 2017-06-26 21:00:00            NaN    NaN    NaN    NaN
# 2017-06-29 21:00:00            NaN    NaN    NaN    NaN
# ...                            ...    ...    ...    ...
# 2022-03-30 21:00:00          53.75  56.93  53.75  56.47
# 2022-04-02 21:00:00          54.55  55.50  54.55  55.02
# 2022-04-06 21:00:00          55.69  55.91  51.85  51.85
# 2022-04-10 21:00:00          52.20  52.20  50.72  51.08
# 2022-04-14 21:00:00          47.40  49.59  47.40  49.59
#
# [463 rows x 272 columns]
